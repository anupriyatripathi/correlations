# %%
options(warn = -1)
library(WGCNA)
options(stringsAsFactors=FALSE)
enableWGCNAThreads()
# Out:
# Loading required package: dynamicTreeCut
# Loading required package: fastcluster
#
# Attaching package: ‘fastcluster’
#
# The following object is masked from ‘package:stats’:
#
#     hclust
# ==========================================================================
# *
# *  Package WGCNA 1.63 loaded.
# *
# *    Important note: It appears that your system supports multi-threading,
# *    but it is not enabled within WGCNA in R.
# *    To allow multi-threading within WGCNA with all available cores, use
# *
# *          allowWGCNAThreads()
# *
# *    within R. Use disableWGCNAThreads() to disable threading if necessary.
# *    Alternatively, set the following environment variable on your system:
# *
# *          ALLOW_WGCNA_THREADS=<number_of_processors>
# *
# *    for example
# *
# *          ALLOW_WGCNA_THREADS=8
# *
# *    To set the environment variable in linux bash shell, type
# *
# *           export ALLOW_WGCNA_THREADS=8
# *
# *     before running R. Other operating systems or shells will
# *     have a similar command to achieve the same aim.
# *
# ==========================================================================
# Attaching package: ‘WGCNA’
#
# The following object is masked from ‘package:stats’:
#
#     cor
# Allowing parallel execution with up to 7 working processes.

# %%
load(file='metab_mapping.RData')
load(file='microb_mapping.RData')

# %%
# choose soft-thresholding power for metab
powers_metab = c(c(1:10), seq(12, 20, by=2)) 
sft_metab = pickSoftThreshold(dat_metab, powerVector=powers_metab, verbose=5)
# Out:
# pickSoftThreshold: will use block size 2238.
#  pickSoftThreshold: calculating connectivity for given powers...
#    ..working on genes 1 through 2238 of 2238
#    Power SFT.R.sq  slope truncated.R.sq mean.k. median.k. max.k.
# 1      1    0.187  0.282          0.520  329.00    337.00  650.0
# 2      2    0.570 -0.545          0.467  124.00     99.20  337.0
# 3      3    0.811 -0.632          0.757   69.30     42.50  224.0
# 4      4    0.847 -0.763          0.822   46.20     26.70  177.0
# 5      5    0.910 -0.826          0.910   34.00     16.80  148.0
# 6      6    0.914 -0.863          0.920   26.60     11.20  127.0
# 7      7    0.877 -0.907          0.881   21.80      8.06  112.0
# 8      8    0.884 -0.935          0.898   18.30      6.24  101.0
# 9      9    0.885 -0.954          0.904   15.80      4.92   92.3
# 10    10    0.875 -0.983          0.895   13.80      4.01   85.0
# 11    12    0.894 -0.998          0.922   11.00      2.66   74.4
# 12    14    0.879 -1.020          0.913    9.15      1.86   66.3
# 13    16    0.851 -1.030          0.892    7.79      1.32   59.8
# 14    18    0.862 -1.030          0.915    6.75      0.97   54.4
# 15    20    0.858 -1.040          0.918    5.94      0.76   49.9

# %%
cex1 = 0.9 # size of red number 
plot(sft_metab$fitIndices[,1], -sign(sft_metab$fitIndices[,3])*sft_metab$fitIndices[,2],
     xlab='Metab Soft Threshold (power)', ylab = 'Scale Free Topology Model Fit',
    type='n', main=paste('Scale independence'))
text(sft_metab$fitIndices[,1], -sign(sft_metab$fitIndices[,3])*sft_metab$fitIndices[,2],
                              labels=powers_metab, cex=cex1, col='red')
abline(h=0.4, col='red') # choose power=3, the lowest power for which the curve flattens out
# Out:
# Plot with title “Scale independence”

# %%
# choose soft-thresholding power for Microb
powers_microb = c(c(1:10), seq(12, 20, by=2))
sft_microb = pickSoftThreshold(dat_microb, powerVector=powers_microb, verbose=5)
# Out:
# pickSoftThreshold: will use block size 2826.
#  pickSoftThreshold: calculating connectivity for given powers...
#    ..working on genes 1 through 2826 of 2826
#    Power SFT.R.sq slope truncated.R.sq mean.k. median.k. max.k.
# 1      1    0.595 -1.91       6.56e-01    34.1     22.70    158
# 2      2    0.254 -3.00       8.23e-02    17.9      8.58    113
# 3      3    0.270 -3.01       1.03e-01    15.8      6.65    110
# 4      4    0.240 -2.77       2.64e-02    14.8      5.96    108
# 5      5    0.223 -2.59       6.89e-03    14.2      5.55    108
# 6      6    0.218 -2.53       3.25e-05    13.8      5.20    107
# 7      7    0.219 -2.53       1.61e-03    13.5      5.10    107
# 8      8    0.579 -1.60       4.58e-01    13.3      5.00    106
# 9      9    0.571 -1.58       4.49e-01    13.1      4.98    106
# 10    10    0.611 -1.53       5.00e-01    13.0      4.86    106
# 11    12    0.590 -1.58       4.73e-01    12.7      4.63    106
# 12    14    0.580 -1.56       4.61e-01    12.6      4.48    105
# 13    16    0.552 -1.60       4.24e-01    12.4      4.30    105
# 14    18    0.541 -1.58       4.12e-01    12.3      4.15    105
# 15    20    0.233 -2.52       2.15e-02    12.2      4.11    105

# %%
cex1 = 0.9 # size of red number 
plot(sft_microb$fitIndices[,1], -sign(sft_microb$fitIndices[,3])*sft_microb$fitIndices[,2],
     xlab='microb Soft Threshold (power)', ylab = 'Scale Free Topology Model Fit',
    type='n', main=paste('Scale independence'))
text(sft_microb$fitIndices[,1], -sign(sft_microb$fitIndices[,3])*sft_microb$fitIndices[,2],
                              labels=powers_microb, cex=cex1, col='red')
abline(h=0.4, col='red') # choose power=8, the lowest power for which the curve flattens out (not the best for microbiome data here)
# Out:
# Plot with title “Scale independence”

# %%
net_metab = blockwiseModules(dat_metab, power=3, TOMtype='unsigned', minModuleSize=10, reassignThreshold=0, 
                                mergeCutHeight=0.25, # numericLabels=TRUE,
                                pamRespectsDendro=FALSE, saveTOMS=TRUE, saveTOMFileBase='laura_TOM')

# %%
net_microb = blockwiseModules(dat_microb, power=8, TOMtype='unsigned', minModuleSize=30, reassignThreshold=0, 
                                mergeCutHeight=0.25, # numericLabels=TRUE,
                                pamRespectsDendro=FALSE, saveTOMS=TRUE, saveTOMFileBase='laura_TOM')

# %%
print(table(net_metab$colors))
print(table(net_microb$colors))
# Out:
#          black           blue          brown           cyan      darkgreen
#             79            269            195             36             23
#       darkgrey    darkmagenta darkolivegreen     darkorange        darkred
#             22             11             12             20             26
#  darkturquoise          green    greenyellow           grey         grey60
#             23             90             39            296             30
#      lightcyan     lightgreen    lightyellow        magenta   midnightblue
#             30             29             27             50             32
#         orange  paleturquoise           pink         purple            red
#             21             16             76             49             82
#      royalblue    saddlebrown         salmon        sienna3        skyblue
#             26             18             37             11             18
#      steelblue            tan      turquoise         violet          white
#             17             39            334             12             18
#         yellow    yellowgreen
#            115             10
#
#     black      blue     brown     green      grey   magenta      pink    purple
#        35        87        76        50      2262        32        34        30
#       red turquoise    yellow
#        35       117        68

# %%
mergedColors_metab = labels2colors(net_metab$colors)
pdf('dendrogram_metab.pdf', width=50, height=30)
plotDendroAndColors(net_metab$dendrograms[[1]], mergedColors_metab[net_metab$blockGenes[[1]]], # net$dendrograms[[1]] is the distance matrix
                   'Module Colors', dendroLabels=FALSE, hang=0.03,
                   addGuide=TRUE, guideHang=0.05, main='milk Metab dendrogram and module')
dev.off()
# Out:
# pdf
#   2

# %%
mergedColors_microb = labels2colors(net_microb$colors)
pdf('dendrogram_microb.pdf', width=50, height=30)
plotDendroAndColors(net_microb$dendrograms[[1]], mergedColors_microb[net_microb$blockGenes[[1]]], # net$dendrograms[[1]] is the distance matrix
                   'Module Colors', dendroLabels=FALSE, hang=0.03,
                   addGuide=TRUE, guideHang=0.05, main='milk microb dendrogram and module')
dev.off()
# Out:
# pdf
#   2

# %%
# save result from clustering
moduleLabels_metab = net_metab$colors
moduleColors_metab = labels2colors(net_metab$colors)
MEs_metab = net_metab$MEs
tree_metab = net_metab$dendrograms[[1]]

moduleLabels_microb = net_microb$colors
moduleColors_microb = labels2colors(net_microb$colors)
MEs_microb = net_microb$MEs
tree_microb = net_microb$dendrograms[[1]]

save(moduleLabels_metab, moduleColors_metab, MEs_metab, tree_metab, 
     file='milk_metab_modules.RData')
save(moduleLabels_microb, moduleColors_microb, MEs_microb, tree_microb, 
     file='milk_microb_modules.RData')
